# %%
# Test Stanza
# https://github.com/stanfordnlp/stanza

# %%
import stanza

# %%
# !pip install stanza
# Out:
# ...
#   Using cached stanza-1.0.1-py3-none-any.whl (193 kB)
# ERROR: Could not find a version that satisfies the requirement torch>=1.3.0 (from stanza) (from versions: 0.1.2, 0.1.2.post1, 0.1.2.post2)
# ERROR: No matching distribution found for torch>=1.3.0 (from stanza)

# %%
# !python -V
# Out:
# Python 3.7.6

# %%
stanza.download('lv')
# Out:
# ...
# 2020-07-07 12:24:00 INFO: Downloading default packages for language: lv (Latvian)...
# ...
# 2020-07-07 12:24:33 INFO: Finished downloading models and saved to C:\Users\vsaules\stanza_resources.

# %%
nlp = stanza.Pipeline('lv')
# Out:
# 2020-07-07 12:25:18 INFO: Loading these models for language: lv (Latvian):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | lvtb    |
# | pos       | lvtb    |
# | lemma     | lvtb    |
# | depparse  | lvtb    |
# ...
#
# 2020-07-07 12:25:18 INFO: Use device: cpu
# 2020-07-07 12:25:18 INFO: Loading: tokenize
# 2020-07-07 12:25:18 INFO: Loading: pos
# 2020-07-07 12:25:19 INFO: Loading: lemma
# 2020-07-07 12:25:19 INFO: Loading: depparse
# 2020-07-07 12:25:20 INFO: Done loading processors!

# %%
with open('books/Purapuķe_Jānis__Leišu_svētbilžu_griezējs___stāsts_iz_agrākās_leišu_dzīves__771023.txt',encoding='utf-8') as f:
    txt = f.read()
len(txt)
# Out:
# 129643

# %%
doc = nlp(txt)

# %%
type(doc)
# Out:
# stanza.models.common.doc.Document

# %%
len(doc.sentences)
# Out:
# 1634

# %%
doc.sentences[3]
# Out:
# [
#   {
#     "id": "1",
#     "text": "Strādnieku",
#     "lemma": "strādnieks",
#     "upos": "NOUN",
#     "xpos": "ncmpg1",
#     "feats": "Case=Gen|Gender=Masc|Number=Plur",
#     "head": 3,
#     "deprel": "nmod",
#     "misc": "start_char=317|end_char=327"
#   },
#   {
#     "id": "2",
#     "text": "skaļajām",
#     "lemma": "skaļš",
#     "upos": "ADJ",
#     "xpos": "affpdyp",
#     "feats": "Case=Dat|Definite=Def|Degree=Pos|Gender=Fem|Number=Plur",
#     "head": 3,
#     "deprel": "amod",
#     "misc": "start_char=328|end_char=336"
#   },
#   {
#     "id": "3",
#     "text": "klaigām",
#     "lemma": "klaiga",
#     "upos": "NOUN",
#     "xpos": "ncfpd4",
#     "feats": "Case=Dat|Gender=Fem|Number=Plur",
#     "head": 4,
#     "deprel": "iobj",
#     "misc": "start_char=337|end_char=344"
#   },
#   {
#     "id": "4",
#     "text": "iztraucētas",
#     "lemma": "iztraucēt",
#     "upos": "VERB",
#     "xpos": "vmnpdfpnpsnpn",
# ...

# %%
doc.sentences[3].print_dependencies()
# Out:
# ('Strādnieku', '3', 'nmod')
# ('skaļajām', '3', 'amod')
# ('klaigām', '4', 'iobj')
# ('iztraucētas', '0', 'root')
# (',', '8', 'punct')
# ('no', '7', 'case')
# ('auzām', '8', 'obl')
# ('izcēlās', '4', 'conj')
# ('irbes', '8', 'nsubj')
# ('un', '13', 'cc')
# ('burkšķinādamas', '12', 'xcomp')
# ('nolaidās', '8', 'conj')
# ('ataugas', '4', 'conj')
# ('malā', '13', 'obl')
# (',', '23', 'punct')
# ('kamēr', '23', 'mark')
# ('pīles', '23', 'nsubj')
# (',', '21', 'punct')
# ('garos', '20', 'amod')
# ('kaklus', '21', 'obj')
# ('izstiepušas', '23', 'xcomp')
# (',', '21', 'punct')
# ('riņķoja', '4', 'conj')
# ('pa', '25', 'case')
# ('gaisu', '23', 'obl')
# (',', '27', 'punct')
# ('meklēdamas', '23', 'xcomp')
# ('derīgu', '29', 'amod')
# ('pančku', '27', 'obj')
# (',', '32', 'punct')
# ('kur', '32', 'advmod')
# ('nolaisties', '29', 'acl')
# (',', '39', 'punct')
# ('Blakus', '38', 'case')
# ('tagadējam', '38', 'amod')
# ('Telšu', '38', 'nmod')
# ('-Možeiku', '38', 'nmod')
# ...

# %%
dir(doc.sentences[3])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_dependencies',
#  '_doc',
#  '_ents',
#  '_process_tokens',
#  '_text',
#  '_tokens',
#  '_words',
#  'build_dependencies',
#  'build_ents',
#  'dependencies',
#  'dependencies_string',
#  'doc',
#  'entities',
#  'ents',
#  'print_dependencies',
#  'print_tokens',
#  'print_words',
#  'text',
#  'to_dict',
#  'tokens',
#  'tokens_string',
#  'words',
#  'words_string']

# %%
doc.sentences[3].print_tokens()
# Out:
# <Token id=1;words=[<Word id=1;text=Strādnieku;lemma=strādnieks;upos=NOUN;xpos=ncmpg1;feats=Case=Gen|Gender=Masc|Number=Plur;head=3;deprel=nmod>]>
# <Token id=2;words=[<Word id=2;text=skaļajām;lemma=skaļš;upos=ADJ;xpos=affpdyp;feats=Case=Dat|Definite=Def|Degree=Pos|Gender=Fem|Number=Plur;head=3;deprel=amod>]>
# <Token id=3;words=[<Word id=3;text=klaigām;lemma=klaiga;upos=NOUN;xpos=ncfpd4;feats=Case=Dat|Gender=Fem|Number=Plur;head=4;deprel=iobj>]>
# <Token id=4;words=[<Word id=4;text=iztraucētas;lemma=iztraucēt;upos=VERB;xpos=vmnpdfpnpsnpn;feats=Aspect=Perf|Case=Nom|Definite=Ind|Degree=Pos|Gender=Fem|Number=Plur|Polarity=Pos|Tense=Past|VerbForm=Part|Voice=Pass;head=0;deprel=root>]>
# <Token id=5;words=[<Word id=5;text=,;lemma=,;upos=PUNCT;xpos=zc;head=8;deprel=punct>]>
# <Token id=6;words=[<Word id=6;text=no;lemma=no;upos=ADP;xpos=sppd;head=7;deprel=case>]>
# ...

# %%
doc.sentences[3].tokens[:6]
# Out:
# [[
#    {
#      "id": "1",
#      "text": "Strādnieku",
#      "lemma": "strādnieks",
#      "upos": "NOUN",
#      "xpos": "ncmpg1",
#      "feats": "Case=Gen|Gender=Masc|Number=Plur",
#      "head": 3,
#      "deprel": "nmod",
#      "misc": "start_char=317|end_char=327"
#    }
#  ],
#  [
#    {
#      "id": "2",
#      "text": "skaļajām",
#      "lemma": "skaļš",
#      "upos": "ADJ",
#      "xpos": "affpdyp",
#      "feats": "Case=Dat|Definite=Def|Degree=Pos|Gender=Fem|Number=Plur",
#      "head": 3,
#      "deprel": "amod",
#      "misc": "start_char=328|end_char=336"
#    }
#  ],
#  [
#    {
#      "id": "3",
#      "text": "klaigām",
#      "lemma": "klaiga",
#      "upos": "NOUN",
#      "xpos": "ncfpd4",
#      "feats": "Case=Dat|Gender=Fem|Number=Plur",
#      "head": 4,
#      "deprel": "iobj",
#      "misc": "start_char=337|end_char=344"
#    }
#  ],
#  [
#    {
#      "id": "4",
#      "text": "iztraucētas",
#      "lemma": "iztraucēt",
#      "upos": "VERB",
# ...
